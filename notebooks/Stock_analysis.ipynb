# %% [markdown]
# Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import sys

# %% [markdown]
# Load Data

# %%
sys.path.append(str(Path().resolve().parent))

from src.stock_analysis import load_stock_data, calculate_indicators, plot_price_and_ma, plot_rsi, plot_macd

# Load data
stock_data = load_stock_data('AAPL')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Loaded AAPL data and saved to T:\week1\nova-financial-solution\data\AAPL_stock.csv

# %% [markdown]
# Calculate technical indicators

# %%
if stock_data is not None:
    stock_data = calculate_indicators(stock_data)
    print(stock_data[['Close', 'MA', 'RSI', 'MACD', 'MACD_Signal', 'MACD_Hist']].tail())
# Out:
# Calculated indicators: MA, RSI, MACD
# Price            Close          MA        RSI      MACD MACD_Signal MACD_Hist
# Ticker            AAPL
# Date
# 2025-05-22  201.360001  206.318570  45.051124 -0.244382   -0.208987 -0.035395
# 2025-05-23  195.270004  205.631774  45.488575 -1.065059   -0.380201 -0.684858
# 2025-05-27  200.210007  205.149035  52.344822 -1.301828   -0.564526 -0.737301
# 2025-05-28  200.419998  204.623365  55.568996 -1.455743   -0.742770 -0.712973
# 2025-05-29  199.949997  204.009779  53.487333 -1.597235   -0.913663 -0.683573

# %% [markdown]
# Plot price and MA

# %%
if stock_data is not None:
    plot_price_and_ma(stock_data, ticker='AAPL')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 if stock_data is not None:
# ----> 2     plot_price_and_ma(stock_data, ticker='AAPL')
#
# File T:\week1\nova-financial-solution\src\stock_analysis.py:72, in plot_price_and_ma(data, ticker, save_path)
#      70 plt.ylabel('Price (USD)')
#      71 plt.legend()
# ---> 72 plt.savefig(save_path)
#      73 plt.close()
#      74 print(f"Saved price and MA plot to {save_path}")
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File t:\week1\nova-financial-solution\venv\Lib\site-packages\PIL\Image.py:2576, in Image.save(self, fp, format, **params)
#    2574         fp = builtins.open(filename, "r+b")
#    2575     else:
# -> 2576         fp = builtins.open(filename, "w+b")
#    2577 else:
#    2578     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'reports/price_ma_plot.png'

# %% [markdown]
# Plot RSI

# %%
if stock_data is not None:
    plot_rsi(stock_data, ticker='AAPL')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 if stock_data is not None:
#       2     plot_rsi(stock_data, ticker='AAPL')
#
# NameError: name 'stock_data' is not defined

# %% [markdown]
# Plot MACD

# %%
if stock_data is not None:
    plot_macd(stock_data, ticker='AAPL')
